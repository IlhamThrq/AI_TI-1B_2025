# %% [markdown]
# <a href="https://colab.research.google.com/github/IlhamThrq/AI_TI-1B_2025/blob/main/CleaningData_WithPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Library

# %%
import pandas as pd

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv('./Data.csv')
df
# Out:
#      Negara    Umur        Gaji Transaksi
# 0   Jakarta    44.0   8000000.0     Tidak
# 1   Bandung    27.0   6700000.0        Ya
# 2  Surabaya    30.0   4500000.0     Tidak
# 3   Bandung    38.0   7500000.0     Tidak
# 4  Surabaya    40.0         NaN        Ya
# 5   Jakarta    35.0  10000000.0        Ya
# 6   Bandung     NaN   8250000.0     Tidak
# 7   Jakarta    48.0   9750000.0        Ya
# 8  Surabaya  1000.0   7674000.0     Tidak
# 9   Jakarta    27.0   6700000.0        Ya

# %%
df.isnull().sum()
# Out:
# Negara       0
# Umur         1
# Gaji         1
# Transaksi    0
# dtype: int64

# %% [markdown]
# ## Mengatasi Missing Values dengan Drop Data

# %% [markdown]
# ### 1. Hapus Data yang kosong (NaN)

# %%
df = pd.read_csv('./Data.csv')
df.dropna(inplace=True)

df
# Out:
#      Negara    Umur        Gaji Transaksi
# 0   Jakarta    44.0   8000000.0     Tidak
# 1   Bandung    27.0   6700000.0        Ya
# 2  Surabaya    30.0   4500000.0     Tidak
# 3   Bandung    38.0   7500000.0     Tidak
# 5   Jakarta    35.0  10000000.0        Ya
# 7   Jakarta    48.0   9750000.0        Ya
# 8  Surabaya  1000.0   7674000.0     Tidak
# 9   Jakarta    27.0   6700000.0        Ya

# %% [markdown]
# ## Mengatasi Missing Values dengan Nilai Baru

# %% [markdown]
# ### 2. Ganti Data yang kosong (NaN) menjadi :
#
# ### <ul><li>Umur = 50 </li><li>Gaji = 25000000</li></ul>

# %%
df = pd.read_csv('./Data.csv')
df['Umur'].fillna(50, inplace=True)
df['Gaji'].fillna(25000000, inplace=True)

df
# Out:
# <ipython-input-5-cefa89afd30c>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Umur'].fillna(50, inplace=True)
# <ipython-input-5-cefa89afd30c>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df
# Out:
#      Negara    Umur        Gaji Transaksi
# 0   Jakarta    44.0   8000000.0     Tidak
# 1   Bandung    27.0   6700000.0        Ya
# 2  Surabaya    30.0   4500000.0     Tidak
# 3   Bandung    38.0   7500000.0     Tidak
# 4  Surabaya    40.0  25000000.0        Ya
# 5   Jakarta    35.0  10000000.0        Ya
# 6   Bandung    50.0   8250000.0     Tidak
# 7   Jakarta    48.0   9750000.0        Ya
# 8  Surabaya  1000.0   7674000.0     Tidak
# 9   Jakarta    27.0   6700000.0        Ya

# %% [markdown]
# ## Mengatasi Missing Values dengan Nilai Mean

# %% [markdown]
# ## 3. Ganti Data Kosong (NaN) pada Umur dan Gaji dengan Nilai Rata-Rata

# %%
df = pd.read_csv('./Data.csv')
mean_umur = df['Umur'].mean();
mean_gaji = df['Gaji'].mean();

df['Umur'].fillna(mean_umur, inplace=True)
df['Gaji'].fillna(mean_gaji, inplace=True)

df
# Out:
# <ipython-input-6-dfa17ca30442>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Umur'].fillna(mean_umur, inplace=True)
# <ipython-input-6-dfa17ca30442>:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df
# Out:
#      Negara         Umur          Gaji Transaksi
# 0   Jakarta    44.000000  8.000000e+06     Tidak
# 1   Bandung    27.000000  6.700000e+06        Ya
# 2  Surabaya    30.000000  4.500000e+06     Tidak
# 3   Bandung    38.000000  7.500000e+06     Tidak
# 4  Surabaya    40.000000  7.674889e+06        Ya
# 5   Jakarta    35.000000  1.000000e+07        Ya
# 6   Bandung   143.222222  8.250000e+06     Tidak
# 7   Jakarta    48.000000  9.750000e+06        Ya
# 8  Surabaya  1000.000000  7.674000e+06     Tidak
# 9   Jakarta    27.000000  6.700000e+06        Ya

# %% [markdown]
# ## Mengatasi Missing Values dengan Nilai Median

# %% [markdown]
# ## 4. Ganti Data Kosong (NaN) pada Umur dan Gaji dengan Nilai Median

# %%
df = pd.read_csv('./Data.csv')
mean_umur = df['Umur'].median();
mean_gaji = df['Gaji'].median();

df['Umur'].fillna(mean_umur, inplace=True)
df['Gaji'].fillna(mean_gaji, inplace=True)

df
# Out:
# <ipython-input-10-3f09d7a429bc>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Umur'].fillna(mean_umur, inplace=True)
# <ipython-input-10-3f09d7a429bc>:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# ## Mengatasi Missing Values dengan Nilai Mode

# %% [markdown]
# ## 5. Ganti Data Kosong (NaN) pada Umur dan Gaji dengan Nilai Modus

# %%
df = pd.read_csv('./Data.csv')
mean_umur = df['Umur'].mode()[0];
mean_gaji = df['Gaji'].mode()[0];

df['Umur'].fillna(mean_umur, inplace=True)
df['Gaji'].fillna(mean_gaji, inplace=True)

df
# Out:
# <ipython-input-11-2c203f330538>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Umur'].fillna(mean_umur, inplace=True)
# <ipython-input-11-2c203f330538>:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# ## Mengatasi Wrong Data dengan Ubah Data

# %% [markdown]
# ## 6. Apabila Ada Umur yang diatas 120 maka ubah menjadi 33

# %%
df = pd.read_csv('./Data.csv')

for x in df.index:
    if df.loc[x, 'Umur'] > 120:
        df.loc[x, 'Umur'] = 33

df
# Out:
#      Negara  Umur        Gaji Transaksi
# 0   Jakarta  44.0   8000000.0     Tidak
# 1   Bandung  27.0   6700000.0        Ya
# 2  Surabaya  30.0   4500000.0     Tidak
# 3   Bandung  38.0   7500000.0     Tidak
# 4  Surabaya  40.0         NaN        Ya
# 5   Jakarta  35.0  10000000.0        Ya
# 6   Bandung   NaN   8250000.0     Tidak
# 7   Jakarta  48.0   9750000.0        Ya
# 8  Surabaya  33.0   7674000.0     Tidak
# 9   Jakarta  27.0   6700000.0        Ya

# %% [markdown]
# ## Tugas Praktikum

# %% [markdown]
# ### 1. Top 5 Customers yang memiliki nilai transaksi paling banyak

# %%
import pandas as pd

df_transactions = pd.read_csv('transactions_1k.csv')
df_customers = pd.read_csv('customers.csv')
df_gasstations = pd.read_csv('gasstations.csv')

df_transactions['Price'] = pd.to_numeric(df_transactions['Price'], errors='coerce')

customer_totals = df_transactions.groupby('CustomerID')['Price'].sum().reset_index(name='TotalPrice')

top_5_customers = pd.merge(customer_totals, df_customers, on='CustomerID', how='left')

top_5_details = pd.merge(top_5_customers, df_transactions, on='CustomerID', how='left')
top_5_details = pd.merge(top_5_details, df_gasstations, on='GasStationID', how='left')

top_5_details = top_5_details.drop_duplicates('CustomerID', keep='first')

result = top_5_details[[
    'CustomerID', 'TransactionID', 'Date', 'Time', 'CardID', 'GasStationID',
    'ProductID', 'Amount', 'Price',  'TotalPrice', 'Segment_x',
     'ChainID', 'Country', 'Segment_y'
]].head(5)

result = result.rename(columns={
    'Currency_x': 'Transaction_Currency',
    'Currency_y': 'Customer_Currency',
    'Segment_x': 'Customer_Segment',
    'Segment_y': 'Station_Segment'
})

result
# Out:
#    CustomerID  TransactionID        Date      Time  CardID  GasStationID  \
# 0          96            401  2012-08-24  09:26:00  764858          5300
# 4         272            414  2012-08-24  11:40:00  622621          5261
# 5         651            739  2012-08-25  19:12:00  595267          3121
# 6         679            579  2012-08-25  09:05:00  752560           267
# 7        1057            315  2012-08-24  13:02:00  585106          3748
#
#    ProductID  Amount   Price  TotalPrice Customer_Segment  ChainID Country  \
# 0        322      29   28.17       81.61              LAM       77     SVK
# 4        322      62   59.76       59.76              LAM      246     SVK
# 5          2      31  771.85      771.85              KAM        4     CZE
# 6          2     107   92.26       92.26              LAM       35     CZE
# 7         23       1  123.91      969.07              SME        4     CZE
#
#   Station_Segment
# 0         Premium
# 4          Noname
# ...

# %% [markdown]
# ### 2. Top 5 Gas stations yang memiliki nilai transaksi paling banyak

# %%
import pandas as pd

df = pd.read_csv('transactions_1k.csv')

df_top5 = df.groupby('GasStationID')['Price'].sum().reset_index()

df_top5 = df_top5.sort_values(by='Price', ascending=False).head(5)

df_top5
# Out:
#      GasStationID    Price
# 395          4347  8557.94
# 0              48  6868.67
# 291          3250  6744.47
# 142          1155  6701.69
# 217          2417  6065.16

# %% [markdown]
# ### 3. Top 5 Jenis produk yang memiliki nilai transaksi paling banyak

# %%
import pandas as pd

df_transactions = pd.read_csv('transactions_1k.csv')
df_products = pd.read_csv('products.csv')

df_merged = pd.merge(df_transactions, df_products, on='ProductID', how='left')

df_top5 = df_merged.groupby(['ProductID', 'Description'])['Price'].sum().reset_index()

df_top5 = df_top5.sort_values(by='Price', ascending=False).head(5)

df_top5 = df_top5.rename(columns={'Price': 'Total Transaction Value'})

df_top5
# Out:
#     ProductID Description  Total Transaction Value
# 0           2       Nafta                345669.45
# 4           9    Diesel +                 27261.03
# 1           5     Natural                 24639.46
# 11         20  Nafta Plus                  7233.72
# 3           8   Natural +                  3999.92

# %% [markdown]
# ### 4. Deskripsi statistik untuk masing - masing hari (23, 24, 25, 26) pada dataset transaction_1k

# %%
import pandas as pd

df = pd.read_csv('transactions_1k.csv')

df['Amount'] = pd.to_numeric(df['Amount'], errors='coerce')
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')

df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d', errors='coerce')

df['Day'] = df['Date'].dt.day

df_filtered = df[df['Day'].isin([23, 24, 25, 26])]

stats_amount = df_filtered.groupby(df_filtered['Date'].dt.strftime('%Y-%m-%d'))['Amount'].describe()
stats_sales = df_filtered.groupby(df_filtered['Date'].dt.strftime('%Y-%m-%d'))['Price'].describe()

stats_combined = pd.concat([stats_amount, stats_sales], axis=1, keys=['Amount', 'Sales'])

stats_combined
# Out:
#            Amount                                                        \
#             count       mean        std  min    25%   50%    75%    max
# Date
# 2012-08-23   10.0  29.600000  24.900692  1.0  21.25  26.5  35.25   91.0
# 2012-08-24  492.0  19.936992  21.949630  0.0   5.00  19.0  27.00  264.0
# 2012-08-25  425.0  18.880000  20.376114  0.0   4.00  17.0  26.00  154.0
# 2012-08-26   73.0  21.219178  18.932810  0.0   6.00  20.0  29.00  101.0
#
#             Sales                                                           \
#             count        mean         std    min      25%     50%      75%
# Date
# 2012-08-23   10.0  685.379000  534.046487  76.42  481.170  619.44  795.095
# 2012-08-24  492.0  409.939736  488.269481   1.76   76.125  332.45  615.395
# 2012-08-25  425.0  426.940071  453.134207   6.09  102.220  370.38  600.850
# 2012-08-26   73.0  487.431370  429.192499   4.74  142.840  437.03  675.520
#
#
#                 max
# Date
# 2012-08-23  1994.71
# ...

# %% [markdown]
# ### 5. Carilah waktu terbaik (hari dan jam) dimana paling banyak user gas station melakukan transaksi !

# %%
import pandas as pd

df = pd.read_csv('transactions_1k.csv')

df['Amount'] = pd.to_numeric(df['Amount'], errors='coerce')
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')

df['Datetime'] = pd.to_datetime(df['Date'] + ' ' + df['Time'], format='%Y-%m-%d %H:%M:%S', errors='coerce')

df['Date'] = df['Datetime'].dt.strftime('%Y-%m-%d')
df['Hour'] = df['Datetime'].dt.hour

result = df.groupby(['Date', 'Hour']).agg({
    'Amount': 'sum',
    'Price': 'sum'
}).reset_index()

result
# Out:
#           Date  Hour  Amount    Price
# 0   2012-08-23     9      79  1785.68
# 1   2012-08-23    20      26   720.89
# 2   2012-08-23    21      91  1994.71
# 3   2012-08-23    22      69  1603.51
# 4   2012-08-23    23      31   749.00
# ..         ...   ...     ...      ...
# 56  2012-08-26     9     310  7146.06
# 57  2012-08-26    10     120  2829.68
# 58  2012-08-26    11      67  1501.13
# 59  2012-08-26    12     152  3428.88
# 60  2012-08-26    13      43  1000.70
#
# [61 rows x 4 columns]

# %% [markdown]
# ### 6. Dari segi bisnis understanding, tujuan utama dari analisis data customer ini adalah

# %% [markdown]
# ### Tujuan Utama Analisis Data Customer dari Perspektif Business Understanding
# ###Dalam konteks pemahaman bisnis, analisis data customer dilakukan bukan sekadar untuk mengetahui perilaku pelanggan, tetapi lebih jauh lagi untuk mendukung pengambilan keputusan strategis yang berdampak langsung pada pertumbuhan bisnis. Berikut adalah tujuan utamanya:
#
# ###Memahami kontribusi pelanggan terhadap pendapatan bisnis
# ### o. Dengan mengetahui pelanggan yang paling sering bertransaksi dan memiliki nilai transaksi tinggi, perusahaan dapat fokus mempertahankan kelompok ini karena mereka menyumbang persentase besar terhadap omzet secara keseluruhan.
#
# ###Menentukan prioritas wilayah operasional dan ekspansi
# ### o.Analisis performa tiap lokasi (gas station) memungkinkan bisnis mengevaluasi wilayah mana yang paling potensial untuk investasi lebih lanjut, atau yang perlu ditingkatkan performanya melalui promosi atau perbaikan layanan.
#
# ###Mengelola portofolio produk secara lebih efisien
# ### o.Mengetahui produk apa yang paling diminati memungkinkan perusahaan mengoptimalkan lini produk, mengurangi biaya produksi barang yang kurang laku, dan meningkatkan ketersediaan produk unggulan.
#
# ###Mengatur sumber daya secara adaptif terhadap perilaku pelanggan
# ### o.Dari data waktu dan hari terjadinya lonjakan transaksi, perusahaan bisa mengatur jam operasional, alokasi staf, dan stok barang agar selalu siap saat permintaan tinggi.
#
# ###Membangun pendekatan pemasaran yang lebih personal dan tepat sasaran
# ### o.Segmentasi berdasarkan frekuensi dan nilai transaksi memberi dasar kuat untuk membuat program pemasaran yang sesuai dengan kebutuhan dan karakteristik masing-masing kelompok pelanggan.
#
# ###Mengembangkan strategi retensi pelanggan berdasarkan data aktual
# ### o.Mengetahui bagaimana pelanggan bertransaksi memungkinkan perusahaan merancang strategi retensi seperti membership tier, cashback, atau penawaran spesial untuk menjaga loyalitas.
#
# ###Memprediksi perilaku pelanggan ke depan secara lebih akurat
# ### o.Data historis bisa digunakan untuk memproyeksikan potensi nilai seorang pelanggan dalam jangka panjang, mendukung perencanaan anggaran dan strategi customer relationship management.
#
# ###Intinya, analisis data customer dari perspektif business understanding bertujuan untuk menyelaraskan strategi bisnis dengan perilaku dan kebutuhan pelanggan secara nyata, demi mencapai efisiensi, profitabilitas, dan pertumbuhan yang berkelanjutan.
